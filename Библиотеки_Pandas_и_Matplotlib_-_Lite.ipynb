# %% [markdown]
# <a href="https://colab.research.google.com/github/Igorvl/Projects/blob/master/%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B8_Pandas_%D0%B8_Matplotlib_%7C_Lite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Ниже дано 2 графика. Сделайте их более простыми для восприятия:
# - подпишите оси - "ось X" и "X и Y"
# - подпишите название графика - "sin(x)/2 и cos(x)"
# - увеличьте размер полотна

# %%
# Исходные графики:

import matplotlib.pyplot as plt    # Импорт модуля pyplot
import numpy as np                 # Импорт библиотеки numpy

x = np.linspace(0, 10, 101)        # Генерация последовательности из 101 числа с шагом в 0.1
y = np.cos(x)                      # Запись cos(x) в переменную y
z = np.sin(x) / 2                  # Запись sin(x) / 2 в переменную z

plt.plot(x, y)                     # Построение графика x, y
plt.plot(x, z)                     # Построение графика x, z
plt.show()                         # Фиксация графика

# %%
# Ваше решение

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 101)
y = np.cos(x)
z = np.sin(x) / 2

plt.figure(figsize=(12,4))
plt.plot(x, y, 'c:', label='cos(x)', linewidth=3, color='lightgreen',
         marker='+', markeredgecolor='black', markersize=5, markevery=20)
plt.plot(x, z, label='sin(x)/2', linewidth=2, color='orange',
         marker='1', markeredgecolor='black', markersize=5, markevery=10)
plt.title('cos(x), sin(x)/2')
plt.legend(loc='lower center')
plt.ylabel('Ось Y')
plt.xlabel('Ось X')
plt.show()

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Загрузите базу данных: [ссылка на скачивание](https://drive.google.com/file/d/1bLiz_81Kb4pMryEalRe66jS38_F6vwMX/view?usp=sharing). Она содержит:
# ```
# - регион
# - страна
# - штат
# - город
# - день
# - месяц
# - год
# - средняя температура за день в градусах Фаренгейта
# ```
#
# Ознакомьтесь с датафреймом. Вычислите количество пустых ячеек в столбце **State**. Заполните пустые ячейки текстом "**state_not_defined**". Убедитесь, что теперь количество пустых ячеек равно нулю.

# %%
#Нужный файл можно скачать через следующий код:
import gdown
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l9/city_temperature.csv', None, quiet=True)
# Out:
# 'city_temperature.csv'

# %%
# Ваше решение
import gdown
import pandas as pd

gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l9/city_temperature.csv', None, quiet=True)
cityTemp = pd.read_csv('/content/city_temperature.csv', low_memory=False)

# %%
print(f'Общее количество ячеек в столбце State: {cityTemp["State"].count()}')
print(f'Количество пустых ячеек в столбце State: {pd.isna(cityTemp["State"]).sum()}')
cityTemp = cityTemp.fillna("state_not_defind")
print(f'Количество пустых ячеек в столбце State опосля замены: {pd.isna(cityTemp["State"]).sum()}')
cityTemp.head(5)
# Out:
# Общее количество ячеек в столбце State: 1455337
# Количество пустых ячеек в столбце State: 1450990
# Количество пустых ячеек в столбце State опосля замены: 0
#    Region  Country             State     City  Month  Day  Year  \
# 0  Africa  Algeria  state_not_defind  Algiers      1    1  1995
# 1  Africa  Algeria  state_not_defind  Algiers      1    2  1995
# 2  Africa  Algeria  state_not_defind  Algiers      1    3  1995
# 3  Africa  Algeria  state_not_defind  Algiers      1    4  1995
# 4  Africa  Algeria  state_not_defind  Algiers      1    5  1995
#
#    AvgTemperature
# 0            64.2
# 1            49.4
# 2            48.8
# 3            46.4
# 4            47.9

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Используя только один метод, выведите на экран следующую информацию:
# - количество непустых записей в каждом столбце
# - тип данных каждого столбца
# - сколько раз встречается каждый тип данных
# - сколько места занимает датафрейм

# %%
# Ваше решение

cityTemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906327 entries, 0 to 2906326
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Region          object
#  1   Country         object
#  2   State           object
#  3   City            object
#  4   Month           int64
#  5   Day             int64
#  6   Year            int64
#  7   AvgTemperature  float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 177.4+ MB

# %% [markdown]
# ### Задание 4

# %% [markdown]
# Создайте резервную копию датафрейма (для этого вспомните с помощью какого метода это делается). Затем создайте новый датафрейм без данных для **US**. Выведете на экран количество строк в новом датафрейме.

# %%
# Ваше решение
cityTempCopy = cityTemp.copy()
cityTempWoUs = cityTempCopy[cityTempCopy['Country'] != 'US']
display(cityTempWoUs, f'Количество строк в новом датафрейме: {len(cityTempWoUs)}')
# Out:
#                                     Region    Country             State  \
# 0                                   Africa    Algeria  state_not_defind
# 1                                   Africa    Algeria  state_not_defind
# 2                                   Africa    Algeria  state_not_defind
# 3                                   Africa    Algeria  state_not_defind
# 4                                   Africa    Algeria  state_not_defind
# ...                                    ...        ...               ...
# 1450985  South/Central America & Carribean  Venezuela  state_not_defind
# 1450986  South/Central America & Carribean  Venezuela  state_not_defind
# 1450987  South/Central America & Carribean  Venezuela  state_not_defind
# 1450988  South/Central America & Carribean  Venezuela  state_not_defind
# 1450989  South/Central America & Carribean  Venezuela  state_not_defind
#
#             City  Month  Day  Year  AvgTemperature
# 0        Algiers      1    1  1995            64.2
# 1        Algiers      1    2  1995            49.4
# 2        Algiers      1    3  1995            48.8
# 3        Algiers      1    4  1995            46.4
# 4        Algiers      1    5  1995            47.9
# ...          ...    ...  ...   ...             ...
# 1450985  Caracas      5    8  2020            80.5
# 1450986  Caracas      5    9  2020            81.3
# 1450987  Caracas      5   10  2020            80.2
# 1450988  Caracas      5   11  2020            81.1
# 1450989  Caracas      5   12  2020            81.0
#
# [1450990 rows x 8 columns]
# 'Количество строк в новом датафрейме: 1450990'

# %% [markdown]
# ### Задание 5

# %% [markdown]
# Добавьте к датафрейму новый столбец, который будет хранить в себе данные по средней температуре в градусах по Цельсию (сейчас столбец **AvgTemperature** хранит температуру в градусах по Фаренгейту). Эта задача решается без использования циклов.

# %%
# Ваше решение
cityTempWoUsWC = cityTempWoUs.copy()
cityTempWoUsWC['AvgTemperatureC'] = (cityTempWoUs['AvgTemperature']- 32) * 5/9
display(cityTempWoUsWC)
# Out:
#                                     Region    Country             State  \
# 0                                   Africa    Algeria  state_not_defind
# 1                                   Africa    Algeria  state_not_defind
# 2                                   Africa    Algeria  state_not_defind
# 3                                   Africa    Algeria  state_not_defind
# 4                                   Africa    Algeria  state_not_defind
# ...                                    ...        ...               ...
# 1450985  South/Central America & Carribean  Venezuela  state_not_defind
# 1450986  South/Central America & Carribean  Venezuela  state_not_defind
# 1450987  South/Central America & Carribean  Venezuela  state_not_defind
# 1450988  South/Central America & Carribean  Venezuela  state_not_defind
# 1450989  South/Central America & Carribean  Venezuela  state_not_defind
#
#             City  Month  Day  Year  AvgTemperature  AvgTemperatureC
# 0        Algiers      1    1  1995            64.2        17.888889
# 1        Algiers      1    2  1995            49.4         9.666667
# 2        Algiers      1    3  1995            48.8         9.333333
# 3        Algiers      1    4  1995            46.4         8.000000
# 4        Algiers      1    5  1995            47.9         8.833333
# ...          ...    ...  ...   ...             ...              ...
# 1450985  Caracas      5    8  2020            80.5        26.944444
# 1450986  Caracas      5    9  2020            81.3        27.388889
# 1450987  Caracas      5   10  2020            80.2        26.777778
# 1450988  Caracas      5   11  2020            81.1        27.277778
# 1450989  Caracas      5   12  2020            81.0        27.222222
#
# [1450990 rows x 9 columns]
